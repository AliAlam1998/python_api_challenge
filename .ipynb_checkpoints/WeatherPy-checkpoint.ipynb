# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in your list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create parameters for the API request
    params = {
        'q': city,
        'appid': weather_api_key  # Make sure to replace 'weather_api_key' with your actual API key
    }

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each city
    try:
        # Perform the API request
        response = requests.get(url, params=params)
        
        # Check if the response status code is 200 (OK)
        if response.status_code == 200:
            # Parse the JSON and retrieve data
            city_weather = response.json()

            # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
            city_lat = city_weather['coord']['lat']
            city_lng = city_weather['coord']['lon']
            city_max_temp = city_weather['main']['temp_max']
            city_humidity = city_weather['main']['humidity']
            city_clouds = city_weather['clouds']['all']
            city_wind = city_weather['wind']['speed']
            city_country = city_weather['sys']['country']
            city_date = city_weather['dt']

            # Append the City information into city_data list
            city_data.append({"City": city, 
                              "Lat": city_lat, 
                              "Lng": city_lng, 
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Date": city_date})
        else:
            print("City not found. Skipping...")

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"An error occurred while processing {city}: {e}")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adamstown
# Processing Record 2 of Set 1 | vorgashor
# Processing Record 3 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 1 | birobidzhan
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | arraias
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | port-aux-francais
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | margaret river
# Processing Record 11 of Set 1 | blackmans bay
# Processing Record 12 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 1 | stanley
# Processing Record 14 of Set 1 | krasnyy chikoy
# Processing Record 15 of Set 1 | twon-brass
# Processing Record 16 of Set 1 | tiksi
# Processing Record 17 of Set 1 | edinburgh of the seven seas
# Processing Record 18 of Set 1 | ebon
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | norilsk
# Processing Record 21 of Set 1 | vilyuysk
# Processing Record 22 of Set 1 | turpan
# Processing Record 23 of Set 1 | akureyri
# Processing Record 24 of Set 1 | kasongo-lunda
# Processing Record 25 of Set 1 | choibalsan
# Processing Record 26 of Set 1 | puerto baquerizo moreno
# Processing Record 27 of Set 1 | sisimiut
# Processing Record 28 of Set 1 | kapuskasing
# Processing Record 29 of Set 1 | cidade velha
# Processing Record 30 of Set 1 | bel ombre
# Processing Record 31 of Set 1 | waitangi
# Processing Record 32 of Set 1 | ghadamis
# Processing Record 33 of Set 1 | fale old settlement
# Processing Record 34 of Set 1 | kavaratti
# Processing Record 35 of Set 1 | broken hill
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | utrik
# Processing Record 38 of Set 1 | russkaya polyana
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | wailua homesteads
# Processing Record 41 of Set 1 | kingston
# Processing Record 42 of Set 1 | uturoa
# Processing Record 43 of Set 1 | peniche
# Processing Record 44 of Set 1 | afaahiti
# Processing Record 45 of Set 1 | nemuro
# Processing Record 46 of Set 1 | thaba-tseka
# Processing Record 47 of Set 1 | saint-philippe
# Processing Record 48 of Set 1 | linxia chengguanzhen
# Processing Record 49 of Set 1 | coquimbo
# City not found. Skipping...
# Processing Record 37 of Set 4 | urengoy
# Processing Record 38 of Set 4 | antsirabe afovoany
# City not found. Skipping...
# Processing Record 39 of Set 4 | bandon
# Processing Record 40 of Set 4 | lauro de freitas
# Processing Record 41 of Set 4 | kawthoung
# City not found. Skipping...
# Processing Record 42 of Set 4 | el fasher
# Processing Record 43 of Set 4 | truckee
# Processing Record 44 of Set 4 | qir moav
# Processing Record 45 of Set 4 | hithadhoo
# Processing Record 46 of Set 4 | bude
# Processing Record 47 of Set 4 | fort mcmurray
# Processing Record 48 of Set 4 | hotan
# Processing Record 49 of Set 4 | pagar alam
# Processing Record 0 of Set 5 | thompson
# Processing Record 1 of Set 5 | badger
# Processing Record 2 of Set 5 | marka
# Processing Record 3 of Set 5 | aripuana
# Processing Record 4 of Set 5 | angaur state
# Processing Record 5 of Set 5 | port mathurin
# Processing Record 6 of Set 5 | pimenta bueno
# Processing Record 7 of Set 5 | pontes e lacerda
# Processing Record 8 of Set 5 | nacozari de garcia
# Processing Record 9 of Set 5 | saint-pierre
# Processing Record 10 of Set 5 | ca mau
# Processing Record 11 of Set 5 | pokaran
# Processing Record 12 of Set 5 | aldan
# Processing Record 13 of Set 5 | ust-nera
# Processing Record 14 of Set 5 | suva
# Processing Record 15 of Set 5 | neyriz
# Processing Record 16 of Set 5 | amguri
# Processing Record 17 of Set 5 | jamai
# Processing Record 18 of Set 5 | palmeira
# Processing Record 19 of Set 5 | victoriaville
# Processing Record 20 of Set 5 | shetpe
# Processing Record 21 of Set 5 | arish
# Processing Record 22 of Set 5 | stuttgart
# Processing Record 23 of Set 5 | barda
# Processing Record 24 of Set 5 | chifeng
# Processing Record 25 of Set 5 | san patricio
# Processing Record 26 of Set 5 | aasiaat
# Processing Record 27 of Set 5 | tura
# Processing Record 28 of Set 5 | talcahuano
# Processing Record 29 of Set 5 | qingdao
# Processing Record 30 of Set 5 | magadan
# Processing Record 31 of Set 5 | tobi village
# City not found. Skipping...
# Processing Record 32 of Set 5 | vadso
# Processing Record 33 of Set 5 | shakhun'ya
# Processing Record 34 of Set 5 | pante makasar
# City not found. Skipping...
# Processing Record 35 of Set 5 | minas de marcona
# Processing Record 36 of Set 5 | mahina
# Processing Record 37 of Set 5 | yelizovo
# Processing Record 38 of Set 5 | iskateley
# Processing Record 39 of Set 5 | vila franca do campo
# Processing Record 40 of Set 5 | lipsko
# Processing Record 41 of Set 5 | novodvinsk
# Processing Record 42 of Set 5 | mili
# Processing Record 43 of Set 5 | aykol
# City not found. Skipping...
# Processing Record 44 of Set 5 | de aar
# Processing Record 45 of Set 5 | teguise
# Processing Record 46 of Set 5 | puerto deseado
# Processing Record 47 of Set 5 | ta`u
# Processing Record 48 of Set 5 | undurkhaan
# Processing Record 49 of Set 5 | shajapur
# Processing Record 0 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 1 of Set 6 | tindouf
# Processing Record 2 of Set 6 | new norfolk
# Processing Record 3 of Set 6 | hamilton
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | nueva gerona
# Processing Record 6 of Set 6 | barkhan
# Processing Record 7 of Set 6 | crane
# Processing Record 8 of Set 6 | sarh
# Processing Record 9 of Set 6 | gadzhiyevo
# Processing Record 10 of Set 6 | lexington
# Processing Record 11 of Set 6 | tazovsky
# Processing Record 12 of Set 6 | naraini
# Processing Record 13 of Set 6 | port lincoln
# Processing Record 14 of Set 6 | kencong
# Processing Record 15 of Set 6 | chernyshevskiy
# Processing Record 16 of Set 6 | ballina
# Processing Record 17 of Set 6 | mega
# Processing Record 18 of Set 6 | usinsk
# Processing Record 19 of Set 6 | sona
# Processing Record 20 of Set 6 | kaa-khem
# Processing Record 21 of Set 6 | veraval
# Processing Record 22 of Set 6 | nar'yan-mar
# Processing Record 23 of Set 6 | praia da vitoria
# Processing Record 24 of Set 6 | cacoal
# Processing Record 25 of Set 6 | holualoa
# Processing Record 26 of Set 6 | nowshahr
# Processing Record 27 of Set 6 | haiku-pauwela
# Processing Record 28 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 29 of Set 6 | fonadhoo
# City not found. Skipping...
# Processing Record 30 of Set 6 | jikamshi
# Processing Record 31 of Set 6 | coruripe
# Processing Record 32 of Set 6 | illizi
# Processing Record 33 of Set 6 | sosnovo-ozerskoye
# Processing Record 34 of Set 6 | dudinka
# Processing Record 35 of Set 6 | constantia
# Processing Record 36 of Set 6 | el alto
# Processing Record 37 of Set 6 | berdigestyakh
# Processing Record 38 of Set 6 | cassilandia
# Processing Record 39 of Set 6 | aykhal
# Processing Record 40 of Set 6 | howard springs
# Processing Record 41 of Set 6 | marietta
# Processing Record 42 of Set 6 | el bauga
# Processing Record 43 of Set 6 | kitimat
# Processing Record 44 of Set 6 | kourou
# Processing Record 45 of Set 6 | qoryooley
# Processing Record 46 of Set 6 | atasu
# Processing Record 47 of Set 6 | nantucket
# Processing Record 48 of Set 6 | taiobeiras
# Processing Record 49 of Set 6 | jayapura
# Processing Record 0 of Set 7 | sevastopol
# Processing Record 1 of Set 7 | al jawf
# Processing Record 2 of Set 7 | lakatoro
# Processing Record 3 of Set 7 | vikhorevka
# Processing Record 4 of Set 7 | rio preto da eva
# Processing Record 5 of Set 7 | itamaraca
# Processing Record 6 of Set 7 | ulladulla
# Processing Record 7 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 8 of Set 7 | bouca
# Processing Record 9 of Set 7 | gafsa
# Processing Record 10 of Set 7 | san fernando
# Processing Record 11 of Set 7 | inhambane
# Processing Record 12 of Set 7 | salym
# Processing Record 13 of Set 7 | crotone
# Processing Record 14 of Set 7 | mersa matruh
# Processing Record 15 of Set 7 | oroqen zizhiqi
# Processing Record 16 of Set 7 | tangalle
# Processing Record 17 of Set 7 | fisterra
# Processing Record 18 of Set 7 | urangan
# Processing Record 19 of Set 7 | seogwipo
# City not found. Skipping...
# Processing Record 20 of Set 7 | mount isa
# Processing Record 21 of Set 7 | amble
# Processing Record 41 of Set 8 | sungailiat
# Processing Record 42 of Set 8 | gobabis
# Processing Record 43 of Set 8 | kimbe
# Processing Record 44 of Set 8 | lihue
# Processing Record 45 of Set 8 | raja
# Processing Record 46 of Set 8 | atamyrat
# Processing Record 47 of Set 8 | ordos
# City not found. Skipping...
# Processing Record 48 of Set 8 | chibougamau
# Processing Record 49 of Set 8 | isabela
# Processing Record 0 of Set 9 | la ronge
# Processing Record 1 of Set 9 | darnah
# Processing Record 2 of Set 9 | susuman
# Processing Record 3 of Set 9 | saint-felicien
# Processing Record 4 of Set 9 | la passe
# Processing Record 5 of Set 9 | ardakan
# Processing Record 6 of Set 9 | dmitrovsk-orlovskiy
# Processing Record 7 of Set 9 | sinabang
# Processing Record 8 of Set 9 | yicheng
# Processing Record 9 of Set 9 | portland
# Processing Record 10 of Set 9 | el nido
# Processing Record 11 of Set 9 | sebezh
# Processing Record 12 of Set 9 | kimovsk
# Processing Record 13 of Set 9 | iranshahr
# Processing Record 14 of Set 9 | souillac
# Processing Record 15 of Set 9 | shingu
# Processing Record 16 of Set 9 | hanzhong
# Processing Record 17 of Set 9 | ketchikan
# Processing Record 18 of Set 9 | bayanhongor
# Processing Record 19 of Set 9 | hami
# Processing Record 20 of Set 9 | macheng
# Processing Record 21 of Set 9 | bossangoa
# Processing Record 22 of Set 9 | nuuk
# Processing Record 23 of Set 9 | gusinoozyorsk
# Processing Record 24 of Set 9 | gorodishche
# Processing Record 25 of Set 9 | northam
# Processing Record 26 of Set 9 | sechura
# Processing Record 27 of Set 9 | ziro
# Processing Record 28 of Set 9 | potosi
# Processing Record 29 of Set 9 | bathsheba
# Processing Record 30 of Set 9 | yarmouth
# Processing Record 31 of Set 9 | broome
# Processing Record 32 of Set 9 | an nuhud
# Processing Record 33 of Set 9 | essaouira
# Processing Record 34 of Set 9 | mount gambier
# Processing Record 35 of Set 9 | amungan
# Processing Record 36 of Set 9 | polyarnyy
# Processing Record 37 of Set 9 | ma'rib
# Processing Record 38 of Set 9 | laayoune plage
# City not found. Skipping...
# Processing Record 39 of Set 9 | n'zeto
# Processing Record 40 of Set 9 | puerto leguizamo
# Processing Record 41 of Set 9 | troitsko-pechorsk
# Processing Record 42 of Set 9 | taksimo
# Processing Record 43 of Set 9 | mandalgovi
# Processing Record 44 of Set 9 | sao joao da barra
# Processing Record 45 of Set 9 | kapa'a
# Processing Record 46 of Set 9 | kerrville
# Processing Record 47 of Set 9 | jawf al maqbabah
# Processing Record 48 of Set 9 | port alfred
# Processing Record 49 of Set 9 | grande prairie
# Processing Record 0 of Set 10 | turkestan
# Processing Record 1 of Set 10 | nuku'alofa
# Processing Record 2 of Set 10 | east ballina
# Processing Record 3 of Set 10 | bikenibeu village
# Processing Record 4 of Set 10 | bandar abbas
# Processing Record 5 of Set 10 | konarka
# Processing Record 6 of Set 10 | narasannapeta
# Processing Record 7 of Set 10 | san andres
# Processing Record 8 of Set 10 | taltal
# Processing Record 9 of Set 10 | zhaotong
# Processing Record 10 of Set 10 | sao vicente
# Processing Record 11 of Set 10 | nadi
# Processing Record 12 of Set 10 | tarauaca
# Processing Record 13 of Set 10 | sidareja
# Processing Record 14 of Set 10 | acapulco de juarez
# Processing Record 15 of Set 10 | vredendal
# Processing Record 16 of Set 10 | mejit
# Processing Record 17 of Set 10 | coahuayana de hidalgo
# Processing Record 18 of Set 10 | erenhot
# Processing Record 19 of Set 10 | new milford
# Processing Record 20 of Set 10 | lesnoy
# Processing Record 21 of Set 10 | businga
# Processing Record 22 of Set 10 | jining
# Processing Record 23 of Set 10 | howrah
# Processing Record 24 of Set 10 | fort st. john
# Processing Record 25 of Set 10 | perugorria
# Processing Record 26 of Set 10 | el porvenir
# Processing Record 27 of Set 10 | gumdag
# Processing Record 28 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 29 of Set 10 | altai
# Processing Record 30 of Set 10 | fort bragg
# Processing Record 31 of Set 10 | tacarigua
# Processing Record 32 of Set 10 | olinda
# Processing Record 33 of Set 10 | civril
# Processing Record 34 of Set 10 | san ignacio
# Processing Record 35 of Set 10 | santyoku
# Processing Record 36 of Set 10 | inarajan village
# Processing Record 37 of Set 10 | newman
# Processing Record 38 of Set 10 | wickenburg
# Processing Record 39 of Set 10 | belyy yar
# Processing Record 40 of Set 10 | oxelosund
# Processing Record 41 of Set 10 | lesosibirsk
# Processing Record 42 of Set 10 | kiruna
# Processing Record 43 of Set 10 | clinton
# Processing Record 44 of Set 10 | dawesville
# Processing Record 45 of Set 10 | partizansk
# Processing Record 46 of Set 10 | lata
# Processing Record 47 of Set 10 | sergach
# Processing Record 48 of Set 10 | nampula
# Processing Record 49 of Set 10 | ndjole
# Processing Record 0 of Set 11 | centralia
# Processing Record 1 of Set 11 | ishigaki
# Processing Record 2 of Set 11 | ambon
# Processing Record 3 of Set 11 | overijse
# Processing Record 4 of Set 11 | vilhena
# Processing Record 5 of Set 11 | san clemente del tuyu
# Processing Record 6 of Set 11 | hue
# Processing Record 7 of Set 11 | inekar
# City not found. Skipping...
# Processing Record 8 of Set 11 | atherton
# Processing Record 9 of Set 11 | kamloops
# Processing Record 10 of Set 11 | taoudenni
# Processing Record 11 of Set 11 | gunnedah
# Processing Record 12 of Set 11 | sault ste. marie
# Processing Record 13 of Set 11 | kendari
# Processing Record 14 of Set 11 | san antonio de pale
# Processing Record 15 of Set 11 | saldanha
# Processing Record 16 of Set 11 | tarnogskiy gorodok
# Processing Record 17 of Set 11 | cockburn town
# Processing Record 18 of Set 11 | ingeniero luis a. huergo
# Processing Record 19 of Set 11 | yugorsk
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | aguas formosas
# Processing Record 22 of Set 11 | cangas del narcea
# Processing Record 23 of Set 11 | bucerias
# Processing Record 24 of Set 11 | ust-tsilma
# Processing Record 25 of Set 11 | abraham's bay
# City not found. Skipping...
# Processing Record 26 of Set 11 | linfen
# Processing Record 27 of Set 11 | sulak
# Processing Record 28 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 29 of Set 11 | piti village
# Processing Record 30 of Set 11 | obo
# Processing Record 31 of Set 11 | fortuna
# Processing Record 32 of Set 11 | semirara
# Processing Record 33 of Set 11 | caleta de carquin
# Processing Record 34 of Set 11 | smithers
# Processing Record 35 of Set 11 | ocean pointe
# City not found. Skipping...
# Processing Record 36 of Set 11 | karratha
# Processing Record 37 of Set 11 | vorkuta
# Processing Record 38 of Set 11 | smirnykh
# Processing Record 39 of Set 11 | izhevsk
# Processing Record 40 of Set 11 | dem'yanovo
# Processing Record 41 of Set 11 | pyhajarvi
# Processing Record 42 of Set 11 | campos dos goytacazes
# Processing Record 43 of Set 11 | severo-yeniseyskiy
# Processing Record 44 of Set 11 | berberati
# Processing Record 45 of Set 11 | laojunmiao
# Processing Record 46 of Set 11 | arinos
# Processing Record 47 of Set 11 | buka
# Processing Record 48 of Set 11 | manicore
# Processing Record 49 of Set 11 | la'ie
# Processing Record 0 of Set 12 | kant
# Processing Record 1 of Set 12 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 12 | shakawe
# Processing Record 3 of Set 12 | aydintepe
# Processing Record 4 of Set 12 | gordonvale
# Processing Record 5 of Set 12 | namtsy
# Processing Record 6 of Set 12 | ghormach
# Processing Record 7 of Set 12 | bakanas
# Processing Record 8 of Set 12 | qamdo
# Processing Record 9 of Set 12 | eirunepe
# Processing Record 10 of Set 12 | hassi messaoud
# Processing Record 11 of Set 12 | bamboo flat
# Processing Record 12 of Set 12 | bubaque
# Processing Record 13 of Set 12 | carboneras
# Processing Record 14 of Set 12 | floro
# Processing Record 15 of Set 12 | moussoro
# Processing Record 16 of Set 12 | krasnoshchekovo
# Processing Record 17 of Set 12 | al ghayzah
# Processing Record 18 of Set 12 | rio grande
# Processing Record 19 of Set 12 | alzamay
# Processing Record 20 of Set 12 | umirim
# Processing Record 21 of Set 12 | port nelson
# Processing Record 22 of Set 12 | quellon
# Processing Record 23 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 24 of Set 12 | thayetmyo
# Processing Record 25 of Set 12 | hamada
# Processing Record 26 of Set 12 | kiunga
# Processing Record 27 of Set 12 | bridgewater
# Processing Record 28 of Set 12 | greymouth
# Processing Record 29 of Set 12 | we
# City not found. Skipping...
# Processing Record 30 of Set 12 | brokopondo
# Processing Record 31 of Set 12 | thunder bay
# Processing Record 32 of Set 12 | horta
# Processing Record 33 of Set 12 | laboulaye
# Processing Record 34 of Set 12 | sur
# Processing Record 35 of Set 12 | acarau
# Processing Record 36 of Set 12 | nogliki
# Processing Record 37 of Set 12 | cheremshan
# Processing Record 38 of Set 12 | san carlos
# Processing Record 39 of Set 12 | hirara
# Processing Record 40 of Set 12 | jeju city
# Processing Record 41 of Set 12 | muroto-misakicho
# Processing Record 42 of Set 12 | robore
# Processing Record 43 of Set 12 | canutama
# Processing Record 44 of Set 12 | kenai
# Processing Record 45 of Set 12 | kingscliff
# Processing Record 46 of Set 12 | ramos arizpe
# Processing Record 47 of Set 12 | luocheng
# Processing Record 48 of Set 12 | kangding
# Processing Record 49 of Set 12 | nishinoomote
# Processing Record 0 of Set 13 | nazyvayevsk
# Processing Record 1 of Set 13 | bayan nur
# City not found. Skipping...
# Processing Record 2 of Set 13 | amahai
# Processing Record 3 of Set 13 | choele choel
# Processing Record 4 of Set 13 | mishkino
# Processing Record 5 of Set 13 | chilecito
# Processing Record 6 of Set 13 | payson
# Processing Record 7 of Set 13 | sassandra
# Processing Record 8 of Set 13 | tobol'sk
# Processing Record 9 of Set 13 | kailahun
# Processing Record 10 of Set 13 | remire-montjoly
# Processing Record 11 of Set 13 | letterkenny
# Processing Record 12 of Set 13 | okha
# Processing Record 13 of Set 13 | east end
# Processing Record 14 of Set 13 | marquette
# Processing Record 15 of Set 13 | bell ville
# Processing Record 16 of Set 13 | yashkul'
# Processing Record 17 of Set 13 | chegdomyn
# Processing Record 18 of Set 13 | margate
# Processing Record 19 of Set 13 | al kharijah
# Processing Record 20 of Set 13 | merizo village
# Processing Record 21 of Set 13 | yasuj
# Processing Record 22 of Set 13 | san borja
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Import the Pandas library
import pandas as pd

# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count for each column
record_counts = city_data_df.count()
print(record_counts)
# Out:
# City          594
# Lat           594
# Lng           594
# Max Temp      594
# Humidity      594
# Cloudiness    594
# Wind Speed    594
# Country       594
# Date          594
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    adamstown -25.0660 -130.1015    293.83        88         100       11.05
# 1    vorgashor  67.5833   63.9500    278.39        99         100        4.94
# 2  birobidzhan  48.8000  132.9500    284.78        72          87        2.63
# 3       albany  42.6001  -73.9662    288.04        94           0        0.89
# 4      arraias -12.9288  -46.9437    301.56        34          65        1.94
#
#   Country        Date
# 0      PN  1696130374
# 1      RU  1696130231
# 2      RU  1696130375
# 3      US  1696130375
# 4      BR  1696130375

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          adamstown -25.0660 -130.1015    293.83        88         100
# 1          vorgashor  67.5833   63.9500    278.39        99         100
# 2        birobidzhan  48.8000  132.9500    284.78        72          87
# 3             albany  42.6001  -73.9662    288.04        94           0
# 4            arraias -12.9288  -46.9437    301.56        34          65
#
#          Wind Speed Country        Date
# City_ID
# 0             11.05      PN  1696130374
# 1              4.94      RU  1696130231
# 2              2.63      RU  1696130375
# 3              0.89      US  1696130375
# 4              1.94      BR  1696130375

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolors="black", alpha=0.5)

# Set the title and labels
plt.title("City Latitude vs. Max Temperature (Date)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Incorporate grid lines
plt.grid()

# Save the figure
plt.savefig("output_data/Fig01.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Build scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolors="black", alpha=0.5)

# Set the title and labels
plt.title("City Latitude vs. Humidity (Date)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Incorporate grid lines
plt.grid()

# Save the figure
plt.savefig("output_data/Fig02.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolors="black", alpha=0.5)

# Set the title and labels
plt.title("City Latitude vs. Cloudiness (Date)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Incorporate grid lines
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Import necessary libraries
import matplotlib.pyplot as plt

# Build scatter plot for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolors="black", alpha=0.5)

# Set the title and labels
plt.title("City Latitude vs. Wind Speed (Date)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Incorporate grid lines
plt.grid()

# Save the figure
plt.savefig("output_data/Fig04.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Define a function to create Linear Regression plots
def create_linear_regression_plot(x_values, y_values, x_label, y_label, title, text_coordinates):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression line
    regress_values = x_values * slope + intercept
    
    # Create a line equation string
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    # Create a scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot the regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the line equation on the plot
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    
    # Set labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Print the correlation coefficient
    print(f"The correlation coefficient (r-value) is: {round(rvalue, 2)}")
    
    # Show plot
    plt.show()

# %%
# Filter the original DataFrame to get Northern Hemisphere data
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          vorgashor  67.5833   63.9500    278.39        99         100
# 2        birobidzhan  48.8000  132.9500    284.78        72          87
# 3             albany  42.6001  -73.9662    288.04        94           0
# 5               hilo  19.7297 -155.0900    302.19        76          20
# 10           stanley  54.8680   -1.6985    287.19        93          40
#
#          Wind Speed Country        Date
# City_ID
# 1              4.94      RU  1696130231
# 2              2.63      RU  1696130375
# 3              0.89      US  1696130375
# 5              2.57      US  1696130376
# 10             3.09      GB  1696130296

# %%
# Filter the original DataFrame to get Southern Hemisphere data
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                adamstown -25.0660 -130.1015    293.83        88         100
# 4                  arraias -12.9288  -46.9437    301.56        34          65
# 6        port-aux-francais -49.3500   70.2167    279.76        94         100
# 7                carnarvon -24.8667  113.6333    294.63        59           1
# 8           margaret river -33.9500  115.0667    289.38        73          97
#
#          Wind Speed Country        Date
# City_ID
# 0             11.05      PN  1696130374
# 4              1.94      BR  1696130375
# 6             18.95      TF  1696130376
# 7              6.75      AU  1696130209
# 8              9.83      AU  1696130165

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Define a function to create and display linear regression plots with annotation
def plot_linear_regression_with_annotation(x_values, y_values, x_label, y_label, title, coordinates):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression values
    regress_values = x_values * slope + intercept
    
    # Create the equation of the regression line
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    # Create the scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot the regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the equation on the plot
    plt.annotate(line_eq, coordinates, fontsize=15, color="red")
    
    # Set the labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Display the correlation coefficient
    print(f"The correlation coefficient (r-value) is: {round(rvalue, 2)}")
    
    # Show the plot
    plt.show()

# Call the function to create and display the linear regression plot with annotation
plot_linear_regression_with_annotation(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"],
                                       "Latitude", "Max Temperature (F)", "Northern Hemisphere - Latitude vs. Max Temperature Linear Regression", (10, 40))
# Out:
# The correlation coefficient (r-value) is: -0.87

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Define a function to create and display linear regression plots with annotation
def plot_linear_regression_with_annotation(x_values, y_values, x_label, y_label, title, coordinates):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression values
    regress_values = x_values * slope + intercept
    
    # Create the equation of the regression line
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    # Create the scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot the regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the equation on the plot
    plt.annotate(line_eq, coordinates, fontsize=15, color="red")
    
    # Set the labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Display the correlation coefficient
    print(f"The correlation coefficient (r-value) is: {round(rvalue, 2)}")
    
    # Show the plot
    plt.show()

# Call the function to create and display the linear regression plot with annotation for Southern Hemisphere Max Temperature vs. Latitude
plot_linear_regression_with_annotation(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"],
                                       "Latitude", "Max Temperature (F)", "Southern Hemisphere - Latitude vs. Max Temperature Linear Regression", (-30, 50))
# Out:
# The correlation coefficient (r-value) is: 0.73

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Import necessary libraries
from scipy.stats import linregress

# Define a function to create and display linear regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, coordinates):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression values
    regress_values = x_values * slope + intercept
    
    # Create the equation of the regression line
    line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2))
    
    # Create the scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot the regression line
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the equation on the plot
    plt.annotate(line_eq, coordinates, fontsize=15, color="red")
    
    # Set the labels and title
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    # Display the correlation coefficient
    print(f"The correlation coefficient (r-value) is: {round(rvalue, 2)}")
    
    # Show the plot
    plt.show()

# Filter the Northern Hemisphere data for Humidity vs. Latitude
northern_hemi_humidity_df = northern_hemi_df["Humidity"]

# Call the function to create and display the linear regression plot for Humidity vs. Latitude in the Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_humidity_df,
                       "Latitude", "Humidity (%)", "Northern Hemisphere - Humidity vs. Latitude Linear Regression", (45, 15))
# Out:
# The correlation coefficient (r-value) is: 0.06

# %%
# Filter the Southern Hemisphere data for Humidity vs. Latitude
southern_hemi_humidity_df = southern_hemi_df["Humidity"]

# Call the function to create and display the linear regression plot for Humidity vs. Latitude in the Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_humidity_df,
                       "Latitude", "Humidity (%)", "Southern Hemisphere - Humidity vs. Latitude Linear Regression", (-50, 20))
# Out:
# The correlation coefficient (r-value) is: 0.13

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Filter the Northern Hemisphere data for Cloudiness vs. Latitude
northern_hemi_cloudiness_df = northern_hemi_df["Cloudiness"]

# Call the function to create and display the linear regression plot for Cloudiness vs. Latitude in the Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_cloudiness_df,
                       "Latitude", "Cloudiness (%)", "Northern Hemisphere - Cloudiness vs. Latitude Linear Regression", (45, 40))
# Out:
# The correlation coefficient (r-value) is: 0.13

# %%
# Filter the Southern Hemisphere data for Cloudiness vs. Latitude
southern_hemi_cloudiness_df = southern_hemi_df["Cloudiness"]

# Call the function to create and display the linear regression plot for Cloudiness vs. Latitude in the Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_cloudiness_df,
                       "Latitude", "Cloudiness (%)", "Southern Hemisphere - Cloudiness vs. Latitude Linear Regression", (-50, 60))
# Out:
# The correlation coefficient (r-value) is: 0.12

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Filter the Northern Hemisphere data for Wind Speed vs. Latitude
northern_hemi_wind_speed_df = northern_hemi_df["Wind Speed"]

# Call the function to create and display the linear regression plot for Wind Speed vs. Latitude in the Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_wind_speed_df,
                       "Latitude", "Wind Speed (mph)", "Northern Hemisphere - Wind Speed vs. Latitude Linear Regression", (45, 25))
# Out:
# The correlation coefficient (r-value) is: 0.0

# %%
# Filter the Southern Hemisphere data for Wind Speed vs. Latitude
southern_hemi_wind_speed_df = southern_hemi_df["Wind Speed"]

# Call the function to create and display the linear regression plot for Wind Speed vs. Latitude in the Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_wind_speed_df,
                       "Latitude", "Wind Speed (mph)", "Southern Hemisphere - Wind Speed vs. Latitude Linear Regression", (-50, 20))
# Out:
# The correlation coefficient (r-value) is: -0.27

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
